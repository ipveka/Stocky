# %% [markdown]
# # Fastquant

# %%
# !pip install fastquant
# !pip install fbprophet

# Package

import fastquant as fastquant

# Functions

from fastquant import get_crypto_data
from fastquant import backtest
from fastquant import get_crypto_data, backtest
from fbprophet import Prophet
from matplotlib import pyplot as plt

# %% [markdown]
# ### Backtesting

# %%
# Get data


data = get_crypto_data("BTC/USDT", "2018-12-01", "2019-12-31")
data.head()
# Out:
#                open     high      low    close        volume
# dt
# 2018-12-01  4041.27  4299.99  3963.01  4190.02  44840.073481
# 2018-12-02  4190.98  4312.99  4103.04  4161.01  38912.154790
# 2018-12-03  4160.55  4179.00  3827.00  3884.01  49094.369163
# 2018-12-04  3884.76  4085.00  3781.00  3951.64  48489.551613
# 2018-12-05  3950.98  3970.00  3745.00  3769.84  44004.799448

# %%
# SMAC

smac = backtest('smac', data, fast_period = 15, slow_period = 40, verbose = False)
# Out:
# ===Global level arguments===
# init_cash : 100000
# buy_prop : 1
# sell_prop : 1
# commission : 0.0075
# stop_loss : None
# stop_trail : None
# ===Strategy level arguments===
# fast_period : 15
# slow_period : 40
# Final Portfolio Value: 156019.54604999995
# Final PnL: 56019.55
# Time used (seconds): 0.15771079063415527
# Optimal parameters: {'init_cash': 100000, 'buy_prop': 1, 'sell_prop': 1, 'commission': 0.0075, 'stop_loss': None, 'stop_trail': None, 'execution_type': 'close', 'channel': None, 'symbol': None, 'allow_short': False, 'short_max': 1.5, 'add_cash_amount': None, 'add_cash_freq': 'M', 'fast_period': 15, 'slow_period': 40}
# ...

# %%
# Optim SMAC

smac_optim = backtest("smac", data, fast_period = range(15, 30, 3), slow_period = range(40, 55, 3), verbose = False)

print(smac_optim[['fast_period', 'slow_period', 'final_value']].head())
# Out:
# ===Global level arguments===
# init_cash : 100000
# buy_prop : 1
# sell_prop : 1
# commission : 0.0075
# stop_loss : None
# stop_trail : None
# ===Strategy level arguments===
# fast_period : 15
# slow_period : 40
# Final Portfolio Value: 156019.54604999995
# Final PnL: 56019.55
# ===Global level arguments===
# init_cash : 100000
# buy_prop : 1
# sell_prop : 1
# commission : 0.0075
# stop_loss : None
# stop_trail : None
# ===Strategy level arguments===
# fast_period : 15
# slow_period : 43
# Final Portfolio Value: 166857.738825
# Final PnL: 66857.74
# ===Global level arguments===
# init_cash : 100000
# buy_prop : 1
# sell_prop : 1
# commission : 0.0075
# stop_loss : None
# stop_trail : None
# ===Strategy level arguments===
# fast_period : 15
# slow_period : 46
# Final Portfolio Value: 166271.111225
# Final PnL: 66271.11
# ===Global level arguments===
# init_cash : 100000
# buy_prop : 1
# sell_prop : 1
# commission : 0.0075
# stop_loss : None
# stop_trail : None
# ...

# %%
# RSI

backtest('rsi', data, rsi_period = 14, rsi_upper = 70, rsi_lower = 30)
# Out:
# Starting Portfolio Value: 100000.00
# ===Global level arguments===
# init_cash : 100000
# buy_prop : 1
# sell_prop : 1
# commission : 0.0075
# stop_loss : None
# stop_trail : None
# ===Strategy level arguments===
# rsi_period : 14
# rsi_upper : 70
# rsi_lower : 30
# 2018-12-15, BUY CREATE, 3211.72
# 2018-12-15, Cash: 100000.0
# 2018-12-15, Price: 3211.72
# 2018-12-15, Buy prop size: 30
# 2018-12-15, Afforded size: 30
# 2018-12-15, Final size: 30
# 2018-12-16, BUY EXECUTED, Price: 3211.72, Cost: 96351.60, Comm: 722.64, Size: 30.00
# 2019-02-18, SELL CREATE, 3907.79
# 2019-02-19, SELL EXECUTED, Price: 3907.79, Cost: 96351.60, Comm: 879.25, Size: -30.00
# 2019-02-19, OPERATION PROFIT, GROSS: 20882.10, NET: 19280.21
# 2019-09-24, BUY CREATE, 8493.14
# 2019-09-24, Cash: 119280.21025
# 2019-09-24, Price: 8493.14
# 2019-09-24, Buy prop size: 13
# 2019-09-24, Afforded size: 13
# 2019-09-24, Final size: 13
# 2019-09-25, BUY EXECUTED, Price: 8493.14, Cost: 110410.82, Comm: 828.08, Size: 13.00
# ...

# %%
# SMAC Crossover

backtest('smac', data, fast_period = 10, slow_period=  30)
# Out:
# Starting Portfolio Value: 100000.00
# ===Global level arguments===
# init_cash : 100000
# buy_prop : 1
# sell_prop : 1
# commission : 0.0075
# stop_loss : None
# stop_trail : None
# ===Strategy level arguments===
# fast_period : 10
# slow_period : 30
# 2019-02-12, BUY CREATE, 3631.46
# 2019-02-12, Cash: 100000.0
# 2019-02-12, Price: 3631.46
# 2019-02-12, Buy prop size: 27
# 2019-02-12, Afforded size: 27
# 2019-02-12, Final size: 27
# 2019-02-13, BUY EXECUTED, Price: 3631.46, Cost: 98049.42, Comm: 735.37, Size: 27.00
# 2019-06-10, SELL CREATE, 7884.90
# 2019-06-11, SELL EXECUTED, Price: 7884.90, Cost: 98049.42, Comm: 1596.69, Size: -27.00
# 2019-06-11, OPERATION PROFIT, GROSS: 114842.88, NET: 112510.82
# 2019-06-16, BUY CREATE, 8953.33
# 2019-06-16, Cash: 212510.8171
# 2019-06-16, Price: 8953.33
# 2019-06-16, Buy prop size: 23
# 2019-06-16, Afforded size: 23
# 2019-06-16, Final size: 23
# 2019-06-17, BUY EXECUTED, Price: 8953.33, Cost: 205926.59, Comm: 1544.45, Size: 23.00
# ...

# %%
# EMAC

backtest('emac', data, fast_period = 10, slow_period = 30)
# Out:
# Starting Portfolio Value: 100000.00
# ===Global level arguments===
# init_cash : 100000
# buy_prop : 1
# sell_prop : 1
# commission : 0.0075
# stop_loss : None
# stop_trail : None
# ===Strategy level arguments===
# fast_period : 10
# slow_period : 30
# 2019-02-11, BUY CREATE, 3631.05
# 2019-02-11, Cash: 100000.0
# 2019-02-11, Price: 3631.05
# 2019-02-11, Buy prop size: 27
# 2019-02-11, Afforded size: 27
# 2019-02-11, Final size: 27
# 2019-02-12, BUY EXECUTED, Price: 3631.05, Cost: 98038.35, Comm: 735.29, Size: 27.00
# 2019-07-22, SELL CREATE, 9864.91
# 2019-07-23, SELL EXECUTED, Price: 9864.91, Cost: 98038.35, Comm: 1997.64, Size: -27.00
# 2019-07-23, OPERATION PROFIT, GROSS: 168314.22, NET: 165581.29
# 2019-08-04, BUY CREATE, 10929.23
# 2019-08-04, Cash: 265581.28809999995
# 2019-08-04, Price: 10929.23
# 2019-08-04, Buy prop size: 24
# 2019-08-04, Afforded size: 24
# 2019-08-04, Final size: 24
# 2019-08-05, BUY EXECUTED, Price: 10929.23, Cost: 262301.52, Comm: 1967.26, Size: 24.00
# ...

# %%
# MACD

backtest('macd', data, fast_period = 12, slow_period = 26, signal_period = 9, sma_period = 30, dir_period = 10)
# Out:
# Starting Portfolio Value: 100000.00
# ===Global level arguments===
# init_cash : 100000
# buy_prop : 1
# sell_prop : 1
# commission : 0.0075
# stop_loss : None
# stop_trail : None
# ===Strategy level arguments===
# fast_period : 12
# slow_period : 26
# signal_period : 9
# sma_period : 30
# dir_period : 10
# 2019-02-05, BUY CREATE, 3471.59
# 2019-02-05, Cash: 100000.0
# 2019-02-05, Price: 3471.59
# 2019-02-05, Buy prop size: 28
# 2019-02-05, Afforded size: 28
# 2019-02-05, Final size: 28
# 2019-02-06, BUY EXECUTED, Price: 3471.59, Cost: 97204.52, Comm: 729.03, Size: 28.00
# 2019-02-27, SELL CREATE, 3813.69
# 2019-02-28, SELL EXECUTED, Price: 3813.69, Cost: 97204.52, Comm: 800.87, Size: -28.00
# 2019-02-28, OPERATION PROFIT, GROSS: 9578.80, NET: 8048.89
# 2019-08-02, BUY CREATE, 10523.75
# 2019-08-02, Cash: 108048.89120000001
# 2019-08-02, Price: 10523.75
# 2019-08-02, Buy prop size: 10
# 2019-08-02, Afforded size: 10
# 2019-08-02, Final size: 10
# ...

# %%
# Bollinger bands

backtest('bbands', data, period = 20, devfactor = 2.0)
# Out:
# Starting Portfolio Value: 100000.00
# ===Global level arguments===
# init_cash : 100000
# buy_prop : 1
# sell_prop : 1
# commission : 0.0075
# stop_loss : None
# stop_trail : None
# ===Strategy level arguments===
# period : 20
# devfactor : 2.0
# 2019-01-29, BUY CREATE, 3411.04
# 2019-01-29, Cash: 100000.0
# 2019-01-29, Price: 3411.04
# 2019-01-29, Buy prop size: 29
# 2019-01-29, Afforded size: 29
# 2019-01-29, Final size: 29
# 2019-01-30, BUY EXECUTED, Price: 3411.04, Cost: 98920.16, Comm: 741.90, Size: 29.00
# 2019-02-08, SELL CREATE, 3665.18
# 2019-02-09, SELL EXECUTED, Price: 3665.18, Cost: 98920.16, Comm: 797.18, Size: -29.00
# 2019-02-09, OPERATION PROFIT, GROSS: 7370.06, NET: 5830.98
# 2019-07-16, BUY CREATE, 9439.59
# 2019-07-16, Cash: 105830.98215000001
# 2019-07-16, Price: 9439.59
# 2019-07-16, Buy prop size: 11
# 2019-07-16, Afforded size: 11
# 2019-07-16, Final size: 11
# 2019-07-17, BUY EXECUTED, Price: 9439.59, Cost: 103835.49, Comm: 778.77, Size: 11.00
# ...

# %%
# Multi

# Use single set of parameters

strats = { 
    "smac": {"fast_period": 35, "slow_period": 50}, 
    "rsi": {"rsi_lower": 30, "rsi_upper": 70} 
} 
res = backtest("multi", data, strats = strats)
res.shape

# Use auto grid search

strats_opt = { 
    "smac": {"fast_period": 35, "slow_period": [40, 50]}, 
    "rsi": {"rsi_lower": [15, 30], "rsi_upper": 70} 
} 

res_opt = backtest("multi", data, strats = strats_opt)
res_opt.shape
# Out:
# Starting Portfolio Value: 100000.00
# ===Global level arguments===
# init_cash : 100000
# buy_prop : 1
# sell_prop : 1
# commission : 0.0075
# stop_loss : None
# stop_trail : None
# ===Strategy level arguments===
# fast_period : 35
# slow_period : 50
# ===Global level arguments===
# init_cash : 100000
# buy_prop : 1
# sell_prop : 1
# commission : 0.0075
# stop_loss : None
# stop_trail : None
# ===Strategy level arguments===
# rsi_period : 14
# rsi_upper : 70
# rsi_lower : 30
# 2018-12-15, BUY CREATE, 3211.72
# 2018-12-15, Cash: 100000.0
# 2018-12-15, Price: 3211.72
# 2018-12-15, Buy prop size: 30
# 2018-12-15, Afforded size: 30
# 2018-12-15, Final size: 30
# 2018-12-16, BUY EXECUTED, Price: 3211.72, Cost: 96351.60, Comm: 722.64, Size: 30.00
# 2019-02-01, SELL CREATE, 3504.77
# 2019-02-02, SELL EXECUTED, Price: 3504.77, Cost: 96351.60, Comm: 788.57, Size: -30.00
# 2019-02-26, BUY CREATE, 3809.23
# 2019-02-26, Cash: 107280.28975
# 2019-02-26, Price: 3809.23
# ...

# %%
# Prophet

# Fit model on closing prices

# ts = data.reset_index()[["dt", "close"]]
# ts.columns = ['ds', 'y']
# m = Prophet(daily_seasonality = True, yearly_seasonality = True).fit(ts)
# forecast = m.make_future_dataframe(periods = 0, freq = 'D')

# Predict and plot

# pred = m.predict(forecast)
# fig1 = m.plot(pred)
# plt.title('BTC/USDT: Forecasted Daily Closing Price', fontsize=25)

# Convert predictions to expected 1 day returns

# expected_1day_return = pred.set_index("ds").yhat.pct_change().shift(-1).multiply(100)

# Backtest the predictions, given that we buy bitcoin when the predicted next day return is > +1.5%, and sell when it's < -1.5%.

# data["custom"] = expected_1day_return.multiply(-1)
# backtest("custom", data.dropna(),upper_limit=1.5, lower_limit=-1.5)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-46-4ea190049289> in <module>
#       5 ts = data.reset_index()[["dt", "close"]]
#       6 ts.columns = ['ds', 'y']
# ----> 7 m = Prophet(daily_seasonality=True, yearly_seasonality=True).fit(ts)
#       8 # forecast = m.make_future_dataframe(periods = 0, freq = 'D')
#       9
#
# /opt/venv/lib/python3.7/site-packages/fbprophet/forecaster.py in fit(self, df, **kwargs)
#    1109         self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
#    1110
# -> 1111         history = self.setup_dataframe(history, initialize_scales=True)
#    1112         self.history = history
#    1113         self.set_auto_seasonalities()
#
# /opt/venv/lib/python3.7/site-packages/fbprophet/forecaster.py in setup_dataframe(self, df, initialize_scales)
# ...
